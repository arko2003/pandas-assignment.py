# %%
import pandas as pd

#a. Reading the autos file into pandas DataFrame
data=pd.read_csv("C:/Users/SOLO's WORK-IN/Downloads/autos.csv")
data
# Out:
#      symboling         make fuel_type aspiration  num_of_doors   body_style  \
# 0            3  alfa-romero       gas        std             2  convertible
# 1            3  alfa-romero       gas        std             2  convertible
# 2            1  alfa-romero       gas        std             2    hatchback
# 3            2         audi       gas        std             4        sedan
# 4            2         audi       gas        std             4        sedan
# ..         ...          ...       ...        ...           ...          ...
# 188         -1        volvo       gas        std             4        sedan
# 189         -1        volvo       gas      turbo             4        sedan
# 190         -1        volvo       gas        std             4        sedan
# 191         -1        volvo    diesel      turbo             4        sedan
# 192         -1        volvo       gas      turbo             4        sedan
#
# ...

# %%
#b.printing out the first 8 entries
data.head(8)
# Out:
#    symboling         make fuel_type aspiration  num_of_doors   body_style  \
# 0          3  alfa-romero       gas        std             2  convertible
# 1          3  alfa-romero       gas        std             2  convertible
# 2          1  alfa-romero       gas        std             2    hatchback
# 3          2         audi       gas        std             4        sedan
# 4          2         audi       gas        std             4        sedan
# 5          2         audi       gas        std             2        sedan
# 6          1         audi       gas        std             4        sedan
# 7          1         audi       gas        std             4        wagon
#
#   drive_wheels engine_location  wheel_base  length  ...  engine_size  \
# 0          rwd           front        88.6   168.8  ...          130
# 1          rwd           front        88.6   168.8  ...          130
# 2          rwd           front        94.5   171.2  ...          152
# ...

# %%
# c.Groupiing the DataFrame by pricesand finding the minimum value
min_df = data.groupby(['make'])['price'].min()
print(min_df)
# Out:
# make
# alfa-romero      13495
# audi             13950
# bmw              16430
# chevrolet         5151
# dodge             5572
# honda             5399
# isuzu             6785
# jaguar           32250
# mazda             5195
# mercedes-benz    25552
# mercury          16503
# mitsubishi        5389
# nissan            5499
# peugot           11900
# plymouth          5572
# porsche          22018
# saab             11850
# subaru            5118
# toyota            5348
# volkswagen        7775
# volvo            12940
# Name: price, dtype: int64

# %%
data.describe()
# Out:
#         symboling  num_of_doors  wheel_base      length       width  \
# count  193.000000    193.000000  193.000000  193.000000  193.000000
# mean     0.797927      3.160622   98.923834  174.326425   65.893782
# std      1.235582      0.989583    6.152409   12.478593    2.137795
# min     -2.000000      2.000000   86.600000  141.100000   60.300000
# 25%      0.000000      2.000000   94.500000  166.300000   64.100000
# 50%      1.000000      4.000000   97.000000  173.200000   65.400000
# 75%      2.000000      4.000000  102.400000  184.600000   66.900000
# max      3.000000      4.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  num_of_cylinders  engine_size        bore  \
# count  193.000000   193.000000        193.000000   193.000000  193.000000
# mean    53.869948  2561.507772          4.419689   128.124352    3.330622
# std      2.394770   526.700026          1.023182    41.590452    0.272385
# ...

# %%
#d. finding the smallest standard deviation
stan= data.groupby(['make'])['price'].std()
print( stan.min())
# Out:
# 754.421632775731

# %%
# e. return the last 2 rows of each group of car make and fuel type
datas=data[['make','fuel_type']]
print(datas.tail(2))
# Out:
#       make fuel_type
# 191  volvo    diesel
# 192  volvo       gas

# %%
# f.replicating the split-apply-combine without groupby
averages={}
#spilting the data into different regions
for make in data['make'].unique():
    tempdf= data[data['make']==make]
#apply an aggregration fuunction 
    average= tempdf['price'].mean()
#combine the data into dataframe
    averages[make]= [average]
aggregate_data = pd.DataFrame.from_dict(averages, orient= 'index', columns= ['price'])
aggregate_data
# Out:
#                       price
# alfa-romero    15498.333333
# audi           17859.166667
# bmw            26118.750000
# chevrolet       6007.000000
# dodge           7790.125000
# honda           8184.692308
# isuzu           8916.500000
# jaguar         34600.000000
# mazda           9852.000000
# mercedes-benz  33647.000000
# mercury        16503.000000
# mitsubishi      9239.769231
# nissan         10415.666667
# peugot         15489.090909
# plymouth        7963.428571
# porsche        31400.500000
# saab           15223.333333
# subaru          8541.250000
# toyota          9885.812500
# volkswagen     10077.500000
# volvo          18063.181818

# %%
# g. creating and separating
data_1 = {'name': ['Frank','Prince','Abigail'],
        'age': [25, 30, 35],
        'gender': ['female','male','male']}
data_2 = {'name': ['Frank','Prince','Abigail'],
        'age': [15, 20, 25],
        'interest': ['music','gaming','dance']}
data1=pd.DataFrame(data_1)
data2=pd.DataFrame(data_2)
data_3=pd.merge(data1,data2, on='name')
data_3
# Out:
#       name  age_x  gender  age_y interest
# 0    Frank     25  female     15    music
# 1   Prince     30    male     20   gaming
# 2  Abigail     35    male     25    dance
